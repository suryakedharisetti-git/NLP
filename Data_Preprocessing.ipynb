# %%
import pandas as pd
import string
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\surya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data = pd.read_csv("./augmented_news_data.csv")
data.head()
# Out:
#   Source                                           Headline
# 0    BBC  Trump v the BBC: What are the hurdles for US p...
# 1    BBC  Cornet v the BBC: What are the hurdle for US p...
# 2    BBC  Israel has destroyed more than 1,500 buildings...
# 3    BBC  Israel has destroyed more than than ace, 500 b...
# 4    BBC  Trump v the BBC: What are the hurdles for US p...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Source    392 non-null    object
#  1   Headline  392 non-null    object
# dtypes: object(2)
# memory usage: 6.3+ KB

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# Length: 392, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(21)

# %%
df_no_duplicates = data.drop_duplicates(keep='first')
print(df_no_duplicates)
# Out:
#     Source                                           Headline
# 0      BBC  Trump v the BBC: What are the hurdles for US p...
# 1      BBC  Cornet v the BBC: What are the hurdle for US p...
# 2      BBC  Israel has destroyed more than 1,500 buildings...
# 3      BBC  Israel has destroyed more than than ace, 500 b...
# 5      BBC  Trump v the BBC: What are the hurdle for u.s. ...
# ..     ...                                                ...
# 387    CNN  One thousand thousand of Ukrainians face dark ...
# 388    CNN  Syrian migrants in Germany face uncertain futu...
# 389    CNN  Syrian migrants in Germany facial expression u...
# 390    CNN  Qantas releases first images of jet that will ...
# 391    CNN  Qantas releases first mental image of jet that...
#
# [371 rows x 2 columns]

# %%
df_no_duplicates['lower_headline'] = df_no_duplicates['Headline'].str.lower()
df_no_duplicates.head()
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_12080\755474358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_duplicates['lower_headline'] = df_no_duplicates['Headline'].str.lower()
#   Source                                           Headline  \
# 0    BBC  Trump v the BBC: What are the hurdles for US p...
# 1    BBC  Cornet v the BBC: What are the hurdle for US p...
# 2    BBC  Israel has destroyed more than 1,500 buildings...
# 3    BBC  Israel has destroyed more than than ace, 500 b...
# 5    BBC  Trump v the BBC: What are the hurdle for u.s. ...
#
#                                       lower_headline
# 0  trump v the bbc: what are the hurdles for us p...
# 1  cornet v the bbc: what are the hurdle for us p...
# 2  israel has destroyed more than 1,500 buildings...
# 3  israel has destroyed more than than ace, 500 b...
# 5  trump v the bbc: what are the hurdle for u.s. ...

# %%
def clean_text(text):
    if isinstance(text, str):
        cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
        return cleaned_text.strip()
    else:
        return ''

# %%
df_no_duplicates['cleaned_text'] = df_no_duplicates['lower_headline'].apply(clean_text)
df_no_duplicates.head()
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_12080\1986691250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_duplicates['cleaned_text'] = df_no_duplicates['lower_headline'].apply(clean_text)
#   Source                                           Headline  \
# 0    BBC  Trump v the BBC: What are the hurdles for US p...
# 1    BBC  Cornet v the BBC: What are the hurdle for US p...
# 2    BBC  Israel has destroyed more than 1,500 buildings...
# 3    BBC  Israel has destroyed more than than ace, 500 b...
# 5    BBC  Trump v the BBC: What are the hurdle for u.s. ...
#
#                                       lower_headline  \
# 0  trump v the bbc: what are the hurdles for us p...
# 1  cornet v the bbc: what are the hurdle for us p...
# 2  israel has destroyed more than 1,500 buildings...
# 3  israel has destroyed more than than ace, 500 b...
# 5  trump v the bbc: what are the hurdle for u.s. ...
#
#                                         cleaned_text
# 0  trump v the bbc what are the hurdles for us pr...
# 1  cornet v the bbc what are the hurdle for us pr...
# 2  israel has destroyed more than  buildings in g...
# 3  israel has destroyed more than than ace  build...
# 5  trump v the bbc what are the hurdle for us pre...

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\surya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\surya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_stopwords(text):
    if isinstance(text, str):
        words = word_tokenize(text)
        print(words)
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        print(filtered_words)
        cleaned_text = ' '.join(filtered_words)
        print(cleaned_text)
        return cleaned_text.strip()
    else:
        return

# %%
df_no_duplicates.to_csv('cleaned_data.csv', index=False)

# %%
stop_words_removal = pd.read_csv('./cleaned_data.csv')
stop_words_removal.head()
# Out:
#   Source                                           Headline  \
# 0    BBC  Trump v the BBC: What are the hurdles for US p...
# 1    BBC  Cornet v the BBC: What are the hurdle for US p...
# 2    BBC  Israel has destroyed more than 1,500 buildings...
# 3    BBC  Israel has destroyed more than than ace, 500 b...
# 4    BBC  Trump v the BBC: What are the hurdle for u.s. ...
#
#                                       lower_headline  \
# 0  trump v the bbc: what are the hurdles for us p...
# 1  cornet v the bbc: what are the hurdle for us p...
# 2  israel has destroyed more than 1,500 buildings...
# 3  israel has destroyed more than than ace, 500 b...
# 4  trump v the bbc: what are the hurdle for u.s. ...
#
#                                         cleaned_text
# 0  trump v the bbc what are the hurdles for us pr...
# 1  cornet v the bbc what are the hurdle for us pr...
# 2  israel has destroyed more than  buildings in g...
# 3  israel has destroyed more than than ace  build...
# 4  trump v the bbc what are the hurdle for us pre...

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\surya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
stop_words_removal['No_stopwords'] = stop_words_removal['cleaned_text'].apply(remove_stopwords)
# Out:
# ['trump', 'v', 'the', 'bbc', 'what', 'are', 'the', 'hurdles', 'for', 'us', 'presidents', 'legal', 'argument']
# ['trump', 'v', 'bbc', 'hurdles', 'us', 'presidents', 'legal', 'argument']
# trump v bbc hurdles us presidents legal argument
# ['cornet', 'v', 'the', 'bbc', 'what', 'are', 'the', 'hurdle', 'for', 'us', 'president', 's', 'sound', 'contestation']
# ['cornet', 'v', 'bbc', 'hurdle', 'us', 'president', 'sound', 'contestation']
# cornet v bbc hurdle us president sound contestation
# ['israel', 'has', 'destroyed', 'more', 'than', 'buildings', 'in', 'gaza', 'since', 'ceasefire']
# ['israel', 'destroyed', 'buildings', 'gaza', 'since', 'ceasefire']
# israel destroyed buildings gaza since ceasefire
# ['israel', 'has', 'destroyed', 'more', 'than', 'than', 'ace', 'building', 'in', 'gaza', 'since', 'ceasefire']
# ['israel', 'destroyed', 'ace', 'building', 'gaza', 'since', 'ceasefire']
# israel destroyed ace building gaza since ceasefire
# ['trump', 'v', 'the', 'bbc', 'what', 'are', 'the', 'hurdle', 'for', 'us', 'president', 'of', 'the', 'united', 'states', 's', 'effectual', 'contestation']
# ['trump', 'v', 'bbc', 'hurdle', 'us', 'president', 'united', 'states', 'effectual', 'contestation']
# trump v bbc hurdle us president united states effectual contestation
# ['state', 'of', 'israel', 'has', 'destroyed', 'more', 'than', 'd', 'buildings', 'in', 'gaza', 'strip', 'since', 'ceasefire']
# ['state', 'israel', 'destroyed', 'buildings', 'gaza', 'strip', 'since', 'ceasefire']
# state israel destroyed buildings gaza strip since ceasefire
# ['trump', 'says', 'he', 'has', 'obligation', 'to', 'sue', 'bbc', 'over', 'speech', 'edit']
# ['trump', 'says', 'obligation', 'sue', 'bbc', 'speech', 'edit']
# trump says obligation sue bbc speech edit
# ['trump', 'says', 'he', 'have', 'got', 'obligation', 'to', 'sue', 'bbc', 'complete', 'language', 'edit']
# ['trump', 'says', 'got', 'obligation', 'sue', 'bbc', 'complete', 'language', 'edit']
# trump says got obligation sue bbc complete language edit
# ['starmer', 'will', 'fight', 'attempts', 'to', 'replace', 'him', 'allies', 'say']
# ['starmer', 'fight', 'attempts', 'replace', 'allies', 'say']
# starmer fight attempts replace allies say
# ['starmer', 'leave', 'fight', 'attempts', 'to', 'supervene', 'upon', 'him', 'allies', 'say']
# ['starmer', 'leave', 'fight', 'attempts', 'supervene', 'upon', 'allies', 'say']
# starmer leave fight attempts supervene upon allies say
# ['suicide', 'bombing', 'in', 'islamabad', 'kills', 'says', 'pakistans', 'interior', 'minister']
# ['suicide', 'bombing', 'islamabad', 'kills', 'says', 'pakistans', 'interior', 'minister']
# suicide bombing islamabad kills says pakistans interior minister
# ['self', 'annihilation', 'bombing', 'in', 'capital', 'of', 'pakistan', 'killing', 'says', 'pakistan', 's', 'internal', 'minister']
# ['self', 'annihilation', 'bombing', 'capital', 'pakistan', 'killing', 'says', 'pakistan', 'internal', 'minister']
# self annihilation bombing capital pakistan killing says pakistan internal minister
# ['us', 'aircraft', 'carrier', 'group', 'arrives', 'in', 'caribbean']
# ['us', 'aircraft', 'carrier', 'group', 'arrives', 'caribbean']
# us aircraft carrier group arrives caribbean
# ['united', 'states', 'of', 'america', 'aircraft', 'carrier', 'group', 'arrives', 'in', 'caribbean']
# ['united', 'states', 'america', 'aircraft', 'carrier', 'group', 'arrives', 'caribbean']
# united states america aircraft carrier group arrives caribbean
# ['protesters', 'break', 'into', 'cop', 'venue', 'in', 'brazil']
# ['protesters', 'break', 'cop', 'venue', 'brazil']
# protesters break cop venue brazil
# ['protesters', 'transgress', 'into', 'cop', 'locus', 'in', 'brazil']
# ['protesters', 'transgress', 'cop', 'locus', 'brazil']
# protesters transgress cop locus brazil
# ['only', 'from', 'the', 'bbc']
# ['bbc']
# bbc
# ['solely', 'from', 'the', 'bbc']
# ['solely', 'bbc']
# solely bbc
# ['how', 'nasa', 'spotted', 'a', 'tsunami', 'in', 'real', 'time']
# ['nasa', 'spotted', 'tsunami', 'real', 'time']
# nasa spotted tsunami real time
# ['how', 'nasa', 'spotted', 'a', 'tsunami', 'in', 'genuine', 'meter']
# ['nasa', 'spotted', 'tsunami', 'genuine', 'meter']
# nasa spotted tsunami genuine meter
# ['how', 'an', 'afghan', 'child', 'bride', 'became', 'one', 'of', 'europes', 'top', 'bodybuilders']
# ['afghan', 'child', 'bride', 'became', 'one', 'europes', 'top', 'bodybuilders']
# afghan child bride became one europes top bodybuilders
# ['how', 'an', 'afghan', 'child', 'st', 'brigid', 'become', 'one', 'and', 'only', 'of', 'europe', 's', 'top', 'bodybuilder']
# ['afghan', 'child', 'st', 'brigid', 'become', 'one', 'europe', 'top', 'bodybuilder']
# afghan child st brigid become one europe top bodybuilder
# ['more', 'news']
# ['news']
# news
# ['more', 'intelligence']
# ['intelligence']
# intelligence
# ['how', 'japan', 'pms', 'taiwan', 'remarks', 'provoked', 'the', 'fury', 'of', 'china']
# ['japan', 'pms', 'taiwan', 'remarks', 'provoked', 'fury', 'china']
# japan pms taiwan remarks provoked fury china
# ['how', 'japan', 'post', 'mortem', 's', 'taiwan', 'remark', 'provoked', 'the', 'fury', 'of', 'china']
# ['japan', 'post', 'mortem', 'taiwan', 'remark', 'provoked', 'fury', 'china']
# japan post mortem taiwan remark provoked fury china
# ['two', 'popular', 'gay', 'dating', 'platforms', 'removed', 'from', 'apple', 'app', 'store', 'in', 'china']
# ['two', 'popular', 'gay', 'dating', 'platforms', 'removed', 'apple', 'app', 'store', 'china']
# two popular gay dating platforms removed apple app store china
# ['two', 'popular', 'homosexual', 'dating', 'platforms', 'take', 'away', 'from', 'apple', 'app', 'store', 'in', 'prc']
# ['two', 'popular', 'homosexual', 'dating', 'platforms', 'take', 'away', 'apple', 'app', 'store', 'prc']
# two popular homosexual dating platforms take away apple app store prc
# ['moment', 'newly', 'opened', 'bridge', 'partially', 'collapses', 'in', 'china']
# ['moment', 'newly', 'opened', 'bridge', 'partially', 'collapses', 'china']
# moment newly opened bridge partially collapses china
# ['moment', 'newly', 'opened', 'nosepiece', 'partially', 'tumble', 'in', 'china']
# ['moment', 'newly', 'opened', 'nosepiece', 'partially', 'tumble', 'china']
# moment newly opened nosepiece partially tumble china
# ['australia', 'at', 'risk', 'of', 'highimpact', 'sabotage', 'from', 'china', 'says', 'spy', 'chief']
# ['australia', 'risk', 'highimpact', 'sabotage', 'china', 'says', 'spy', 'chief']
# australia risk highimpact sabotage china says spy chief
# ['australia', 'at', 'hazard', 'of', 'in', 'high', 'spirits', 'impact', 'sabotage', 'from', 'mainland', 'china', 'says', 'undercover', 'agent', 'chief']
# ['australia', 'hazard', 'high', 'spirits', 'impact', 'sabotage', 'mainland', 'china', 'says', 'undercover', 'agent', 'chief']
# australia hazard high spirits impact sabotage mainland china says undercover agent chief
# ['evidence', 'of', 'ancient', 'treeclimbing', 'drop', 'crocs', 'found', 'in', 'australia']
# ['evidence', 'ancient', 'treeclimbing', 'drop', 'crocs', 'found', 'australia']
# evidence ancient treeclimbing drop crocs found australia
# ['grounds', 'of', 'ancient', 'tree', 'climbing', 'drop', 'crocs', 'find', 'in', 'australia']
# ['grounds', 'ancient', 'tree', 'climbing', 'drop', 'crocs', 'find', 'australia']
# grounds ancient tree climbing drop crocs find australia
# ['indias', 'startups', 'fire', 'up', 'public', 'markets', 'amid', 'valuation', 'concerns']
# ['indias', 'startups', 'fire', 'public', 'markets', 'amid', 'valuation', 'concerns']
# indias startups fire public markets amid valuation concerns
# ['republic', 'of', 'india', 's', 'start', 'ups', 'fervidness', 'up', 'public', 'markets', 'amid', 'valuation', 'concerns']
# ['republic', 'india', 'start', 'ups', 'fervidness', 'public', 'markets', 'amid', 'valuation', 'concerns']
# republic india start ups fervidness public markets amid valuation concerns
# ['china', 'needs', 'its', 'youth', 'to', 'spend', 'but', 'they', 'are', 'embracing', 'frugality']
# ['china', 'needs', 'youth', 'spend', 'embracing', 'frugality']
# china needs youth spend embracing frugality
# ['china', 'needs', 'its', 'youth', 'to', 'spend', 'but', 'they', 'be', 'embracing', 'frugality']
# ['china', 'needs', 'youth', 'spend', 'embracing', 'frugality']
# china needs youth spend embracing frugality
# ['must', 'watch']
# ['must', 'watch']
# must watch
# ['moldiness', 'watch']
# ['moldiness', 'watch']
# moldiness watch
# ['protesters', 'clash', 'with', 'security', 'at', 'cop', 'climate', 'talks', 'in', 'brazil']
# ['protesters', 'clash', 'security', 'cop', 'climate', 'talks', 'brazil']
# protesters clash security cop climate talks brazil
# ['protesters', 'clash', 'with', 'security', 'at', 'cop', 'climate', 'talks', 'in', 'brasil']
# ['protesters', 'clash', 'security', 'cop', 'climate', 'talks', 'brasil']
# protesters clash security cop climate talks brasil
# ['trump', 'and', 'obama', 'honour', 'us', 'troops', 'for', 'veterans', 'day']
# ['trump', 'obama', 'honour', 'us', 'troops', 'veterans', 'day']
# trump obama honour us troops veterans day
# ['trump', 'and', 'obama', 'honor', 'us', 'troop', 'for', 'veterans', 'day']
# ['trump', 'obama', 'honor', 'us', 'troop', 'veterans', 'day']
# trump obama honor us troop veterans day
# ['suicide', 'attack', 'outside', 'pakistan', 'court', 'kills']
# ['suicide', 'attack', 'outside', 'pakistan', 'court', 'kills']
# suicide attack outside pakistan court kills
# ['suicide', 'attack', 'outside', 'islamic', 'republic', 'of', 'pakistan', 'court', 'pour', 'down']
# ['suicide', 'attack', 'outside', 'islamic', 'republic', 'pakistan', 'court', 'pour']
# suicide attack outside islamic republic pakistan court pour
# ['the', 'kenyan', 'startup', 'aiming', 'to', 'electrify', 'african', 'transport']
# ['kenyan', 'startup', 'aiming', 'electrify', 'african', 'transport']
# kenyan startup aiming electrify african transport
# ['the', 'kenyan', 'starting', 'signal', 'up', 'aiming', 'to', 'electrify', 'african', 'transportation']
# ['kenyan', 'starting', 'signal', 'aiming', 'electrify', 'african', 'transportation']
# kenyan starting signal aiming electrify african transportation
# ['lion', 'saves', 'pregnant', 'hyena', 'from', 'wild', 'dog', 'attack']
# ['lion', 'saves', 'pregnant', 'hyena', 'wild', 'dog', 'attack']
# lion saves pregnant hyena wild dog attack
# ['lion', 'saves', 'fraught', 'hyena', 'from', 'raving', 'mad', 'dog', 'attack']
# ['lion', 'saves', 'fraught', 'hyena', 'raving', 'mad', 'dog', 'attack']
# lion saves fraught hyena raving mad dog attack
# ['im', 'very', 'proud', 'of', 'our', 'journalists', 'says', 'outgoing', 'bbc', 'director', 'general']
# ['im', 'proud', 'journalists', 'says', 'outgoing', 'bbc', 'director', 'general']
# im proud journalists says outgoing bbc director general
# ['i', 'm', 'really', 'proud', 'of', 'our', 'journalists', 'say', 'outgoing', 'bbc', 'film', 'director', 'general']
# ['really', 'proud', 'journalists', 'say', 'outgoing', 'bbc', 'film', 'director', 'general']
# really proud journalists say outgoing bbc film director general
# ['what', 'would', 'pundits', 'change', 'about', 'football']
# ['would', 'pundits', 'change', 'football']
# would pundits change football
# ['government', 'just', 'do', 'your', 'job', 'frustration', 'at', 'us', 'airports', 'as', 'shutdown', 'delays', 'continue']
# ['government', 'job', 'frustration', 'us', 'airports', 'shutdown', 'delays', 'continue']
# government job frustration us airports shutdown delays continue
# ['government', 'just', 'do', 'your', 'job', 'defeat', 'at', 'us', 'airdrome', 'as', 'shutdown', 'delays', 'continue']
# ['government', 'job', 'defeat', 'us', 'airdrome', 'shutdown', 'delays', 'continue']
# government job defeat us airdrome shutdown delays continue
# ['culture']
# ['culture']
# culture
# ['finish']
# ['finish']
# finish
# ['global', 'girl', 'group', 'katseye', 'have', 'received', 'thousands', 'of', 'death', 'threats']
# ['global', 'girl', 'group', 'katseye', 'received', 'thousands', 'death', 'threats']
# global girl group katseye received thousands death threats
# ['global', 'girl', 'mathematical', 'group', 'katseye', 'have', 'incur', 'thousands', 'of', 'death', 'threats']
# ['global', 'girl', 'mathematical', 'group', 'katseye', 'incur', 'thousands', 'death', 'threats']
# global girl mathematical group katseye incur thousands death threats
# ['business']
# ['business']
# business
# ['commercial', 'enterprise']
# ['commercial', 'enterprise']
# commercial enterprise
# ['starbucks', 'baristas', 'are', 'striking', 'again', 'will', 'that', 'hold', 'back', 'the', 'chains', 'recovery']
# ['starbucks', 'baristas', 'striking', 'hold', 'back', 'chains', 'recovery']
# starbucks baristas striking hold back chains recovery
# ['starbucks', 'baristas', 'are', 'striking', 'over', 'again', 'will', 'that', 'book', 'back', 'the', 'chain', 's', 'retrieval']
# ['starbucks', 'baristas', 'striking', 'book', 'back', 'chain', 'retrieval']
# starbucks baristas striking book back chain retrieval
# ['us', 'canada', 'news']
# ['us', 'canada', 'news']
# us canada news
# ['us', 'canada', 'word']
# ['us', 'canada', 'word']
# us canada word
# ['jfks', 'grandson', 'jack', 'schlossberg', 'to', 'run', 'for', 'congress']
# ['jfks', 'grandson', 'jack', 'schlossberg', 'run', 'congress']
# jfks grandson jack schlossberg run congress
# ['jfk', 's', 'grandson', 'jack', 'schlossberg', 'to', 'lam', 'for', 'congress']
# ['jfk', 'grandson', 'jack', 'schlossberg', 'lam', 'congress']
# jfk grandson jack schlossberg lam congress
# ['indiana', 'joins', 'growing', 'us', 'battle', 'over', 'redrawing', 'electoral', 'maps']
# ['indiana', 'joins', 'growing', 'us', 'battle', 'redrawing', 'electoral', 'maps']
# indiana joins growing us battle redrawing electoral maps
# ['indiana', 'joins', 'grow', 'us', 'battle', 'over', 'redrawing', 'electoral', 'function']
# ['indiana', 'joins', 'grow', 'us', 'battle', 'redrawing', 'electoral', 'function']
# indiana joins grow us battle redrawing electoral function
# ['families', 'of', 'camp', 'mystic', 'victims', 'sue', 'owners', 'over', 'deadly', 'texas', 'flood']
# ['families', 'camp', 'mystic', 'victims', 'sue', 'owners', 'deadly', 'texas', 'flood']
# families camp mystic victims sue owners deadly texas flood
# ['families', 'of', 'refugee', 'camp', 'mystic', 'victims', 'eugene', 'sue', 'owners', 'over', 'lifelessly', 'texas', 'flood']
# ['families', 'refugee', 'camp', 'mystic', 'victims', 'eugene', 'sue', 'owners', 'lifelessly', 'texas', 'flood']
# families refugee camp mystic victims eugene sue owners lifelessly texas flood
# ['trump', 'asks', 'supreme', 'court', 'to', 'overturn', 'e', 'jean', 'carroll', 'verdict']
# ['trump', 'asks', 'supreme', 'court', 'overturn', 'e', 'jean', 'carroll', 'verdict']
# trump asks supreme court overturn e jean carroll verdict
# ['trump', 'asks', 'supreme', 'lawcourt', 'to', 'overturn', 'e', 'jean', 'charles', 'dodgson', 'verdict']
# ['trump', 'asks', 'supreme', 'lawcourt', 'overturn', 'e', 'jean', 'charles', 'dodgson', 'verdict']
# trump asks supreme lawcourt overturn e jean charles dodgson verdict
# ['more', 'world', 'news']
# ['world', 'news']
# world news
# ['more', 'mankind', 'news']
# ['mankind', 'news']
# mankind news
# ['thailand', 'extradites', 'owner', 'of', 'myanmar', 'scam', 'city', 'to', 'china']
# ['thailand', 'extradites', 'owner', 'myanmar', 'scam', 'city', 'china']
# thailand extradites owner myanmar scam city china
# ['thailand', 'deport', 'owner', 'of', 'myanmar', 'diddle', 'city', 'to', 'china']
# ['thailand', 'deport', 'owner', 'myanmar', 'diddle', 'city', 'china']
# thailand deport owner myanmar diddle city china
# ['schools', 'go', 'hybrid', 'as', 'delhis', 'air', 'quality', 'worsens']
# ['schools', 'go', 'hybrid', 'delhis', 'air', 'quality', 'worsens']
# schools go hybrid delhis air quality worsens
# ['school', 'day', 'go', 'hybrid', 'as', 'delhi', 's', 'strain', 'character', 'worsens']
# ['school', 'day', 'go', 'hybrid', 'delhi', 'strain', 'character', 'worsens']
# school day go hybrid delhi strain character worsens
# ['dominican', 'republic', 'suffers', 'nationwide', 'power', 'cut', 'after', 'cascade', 'of', 'failures']
# ['dominican', 'republic', 'suffers', 'nationwide', 'power', 'cut', 'cascade', 'failures']
# dominican republic suffers nationwide power cut cascade failures
# ['dominican', 'republic', 'suffers', 'nationwide', 'superpower', 'cut', 'after', 'cascade', 'of', 'bankruptcy']
# ['dominican', 'republic', 'suffers', 'nationwide', 'superpower', 'cut', 'cascade', 'bankruptcy']
# dominican republic suffers nationwide superpower cut cascade bankruptcy
# ['how', 'jihadists', 'have', 'brought', 'a', 'nation', 'to', 'a', 'standstill', 'with', 'their', 'fuel', 'blockade']
# ['jihadists', 'brought', 'nation', 'standstill', 'fuel', 'blockade']
# jihadists brought nation standstill fuel blockade
# ['how', 'jihadists', 'have', 'brought', 'a', 'nation', 'to', 'a', 'standstill', 'with', 'their', 'fuel', 'encirclement']
# ['jihadists', 'brought', 'nation', 'standstill', 'fuel', 'encirclement']
# jihadists brought nation standstill fuel encirclement
# ['clientele']
# ['clientele']
# clientele
# ['four', 'potential', 'obstacles', 'in', 'house', 'vote', 'to', 'end', 'us', 'shutdown']
# ['four', 'potential', 'obstacles', 'house', 'vote', 'end', 'us', 'shutdown']
# four potential obstacles house vote end us shutdown
# ['four', 'possible', 'obstacles', 'in', 'house', 'vote', 'to', 'end', 'america', 'shutdown']
# ['four', 'possible', 'obstacles', 'house', 'vote', 'end', 'america', 'shutdown']
# four possible obstacles house vote end america shutdown
# ['new', 'consoles', 'used', 'to', 'come', 'out', 'every', 'five', 'years', 'so', 'wheres', 'the', 'playstation']
# ['new', 'consoles', 'used', 'come', 'every', 'five', 'years', 'wheres', 'playstation']
# new consoles used come every five years wheres playstation
# ['new', 'console', 'table', 'used', 'to', 'come', 'forbidden', 'every', 'five', 'year', 'hence', 'where', 's', 'the', 'playstation']
# ['new', 'console', 'table', 'used', 'come', 'forbidden', 'every', 'five', 'year', 'hence', 'playstation']
# new console table used come forbidden every five year hence playstation
# ['uk', 'toy', 'sales', 'up', 'as', 'kidults', 'buy', 'lego', 'and', 'pokmon']
# ['uk', 'toy', 'sales', 'kidults', 'buy', 'lego', 'pokmon']
# uk toy sales kidults buy lego pokmon
# ['uk', 'miniature', 'sales', 'up', 'as', 'kidults', 'buy', 'lego', 'set', 'and', 'pokmon']
# ['uk', 'miniature', 'sales', 'kidults', 'buy', 'lego', 'set', 'pokmon']
# uk miniature sales kidults buy lego set pokmon
# ['battle', 'over', 'chinese', 'chipmaker', 'rocks', 'global', 'car', 'industry']
# ['battle', 'chinese', 'chipmaker', 'rocks', 'global', 'car', 'industry']
# battle chinese chipmaker rocks global car industry
# ['battle', 'over', 'chinese', 'chip', 'maker', 'sway', 'global', 'elevator', 'car', 'industry']
# ['battle', 'chinese', 'chip', 'maker', 'sway', 'global', 'elevator', 'car', 'industry']
# battle chinese chip maker sway global elevator car industry
# ['sport']
# ['sport']
# sport
# ['mutation']
# ['mutation']
# mutation
# ['var', 'has', 'to', 'rein', 'its', 'neck', 'in', 'how', 'id', 'change', 'football', 'for', 'the', 'fans']
# ['var', 'rein', 'neck', 'id', 'change', 'football', 'fans']
# var rein neck id change football fans
# ['var', 'have', 'to', 'rein', 'it', 'neck', 'opening', 'in', 'how', 'atomic', 'number', 'd', 'alteration', 'football', 'for', 'the', 'fans']
# ['var', 'rein', 'neck', 'opening', 'atomic', 'number', 'alteration', 'football', 'fans']
# var rein neck opening atomic number alteration football fans
# ['kerr', 'relishing', 'every', 'moment', 'after', 'first', 'chelsea', 'start', 'in', 'days']
# ['kerr', 'relishing', 'every', 'moment', 'first', 'chelsea', 'start', 'days']
# kerr relishing every moment first chelsea start days
# ['kerr', 'relishing', 'every', 'import', 'after', 'first', 'chelsea', 'start', 'in', 'clarence', 'day']
# ['kerr', 'relishing', 'every', 'import', 'first', 'chelsea', 'start', 'clarence', 'day']
# kerr relishing every import first chelsea start clarence day
# ['webb', 'backs', 'officials', 'over', 'disallowed', 'liverpool', 'goal']
# ['webb', 'backs', 'officials', 'disallowed', 'liverpool', 'goal']
# webb backs officials disallowed liverpool goal
# ['webb', 'backs', 'officials', 'ended', 'disallowed', 'liverpool', 'goal']
# ['webb', 'backs', 'officials', 'ended', 'disallowed', 'liverpool', 'goal']
# webb backs officials ended disallowed liverpool goal
# ['wolff', 'to', 'sell', 'stake', 'valuing', 'mercedes', 'f', 'at', 'bn']
# ['wolff', 'sell', 'stake', 'valuing', 'mercedes', 'f', 'bn']
# wolff sell stake valuing mercedes f bn
# ['kaspar', 'friedrich', 'wolff', 'to', 'sell', 'stake', 'assess', 'mercedes', 'f', 'at', 'quatern', 'bn']
# ['kaspar', 'friedrich', 'wolff', 'sell', 'stake', 'assess', 'mercedes', 'f', 'quatern', 'bn']
# kaspar friedrich wolff sell stake assess mercedes f quatern bn
# ['recommended', 'audio']
# ['recommended', 'audio']
# recommended audio
# ['recommended', 'sound']
# ['recommended', 'sound']
# recommended sound
# ['witness', 'history']
# ['witness', 'history']
# witness history
# ['attestor', 'history']
# ['attestor', 'history']
# attestor history
# ['the', 'interview']
# ['interview']
# interview
# ['the', 'consultation']
# ['consultation']
# consultation
# ['business', 'daily']
# ['business', 'daily']
# business daily
# ['outlook']
# ['outlook']
# outlook
# ['mentality']
# ['mentality']
# mentality
# ['the', 'documentary', 'podcast']
# ['documentary', 'podcast']
# documentary podcast
# ['clientele', 'daily']
# ['clientele', 'daily']
# clientele daily
# ['the', 'infinite', 'monkey', 'cage']
# ['infinite', 'monkey', 'cage']
# infinite monkey cage
# ['the', 'infinite', 'rapscallion', 'cage']
# ['infinite', 'rapscallion', 'cage']
# infinite rapscallion cage
# ['tech']
# ['tech']
# tech
# ['technical', 'school']
# ['technical', 'school']
# technical school
# ['uk', 'seeking', 'to', 'curb', 'ai', 'child', 'sex', 'abuse', 'imagery', 'with', 'tougher', 'testing']
# ['uk', 'seeking', 'curb', 'ai', 'child', 'sex', 'abuse', 'imagery', 'tougher', 'testing']
# uk seeking curb ai child sex abuse imagery tougher testing
# ['uk', 'seeking', 'to', 'curb', 'bradypus', 'tridactylus', 'child', 'sexuality', 'abuse', 'imagery', 'with', 'tougher', 'examination']
# ['uk', 'seeking', 'curb', 'bradypus', 'tridactylus', 'child', 'sexuality', 'abuse', 'imagery', 'tougher', 'examination']
# uk seeking curb bradypus tridactylus child sexuality abuse imagery tougher examination
# ['man', 'dances', 'for', 'hours', 'to', 'break', 'video', 'game', 'marathon', 'record']
# ['man', 'dances', 'hours', 'break', 'video', 'game', 'marathon', 'record']
# man dances hours break video game marathon record
# ['man', 'dance', 'for', 'gross', 'hours', 'to', 'break', 'video', 'game', 'marathon', 'phonograph', 'recording']
# ['man', 'dance', 'gross', 'hours', 'break', 'video', 'game', 'marathon', 'phonograph', 'recording']
# man dance gross hours break video game marathon phonograph recording
# ['cryptoqueen', 'who', 'fled', 'china', 'for', 'london', 'mansion', 'jailed', 'over', 'bn', 'bitcoin', 'stash']
# ['cryptoqueen', 'fled', 'china', 'london', 'mansion', 'jailed', 'bn', 'bitcoin', 'stash']
# cryptoqueen fled china london mansion jailed bn bitcoin stash
# ['cryptoqueen', 'who', 'fly', 'china', 'for', 'london', 'planetary', 'house', 'jailed', 'over', 'bn', 'bitcoin', 'stash']
# ['cryptoqueen', 'fly', 'china', 'london', 'planetary', 'house', 'jailed', 'bn', 'bitcoin', 'stash']
# cryptoqueen fly china london planetary house jailed bn bitcoin stash
# ['tiktok', 'creator', 'so', 'sorry', 'over', 'cancer', 'diagnosis', 'lie']
# ['tiktok', 'creator', 'sorry', 'cancer', 'diagnosis', 'lie']
# tiktok creator sorry cancer diagnosis lie
# ['tiktok', 'divine', 'so', 'sorry', 'over', 'cancer', 'diagnosis', 'trygve', 'halvden', 'lie']
# ['tiktok', 'divine', 'sorry', 'cancer', 'diagnosis', 'trygve', 'halvden', 'lie']
# tiktok divine sorry cancer diagnosis trygve halvden lie
# ['science', 'health']
# ['science', 'health']
# science health
# ['scientific', 'discipline', 'health']
# ['scientific', 'discipline', 'health']
# scientific discipline health
# ['my', 'son', 'has', 'childhood', 'dementia', 'im', 'heartbroken']
# ['son', 'childhood', 'dementia', 'im', 'heartbroken']
# son childhood dementia im heartbroken
# ['my', 'logos', 'have', 'childhood', 'dementia', 'i', 'm', 'heartbroken']
# ['logos', 'childhood', 'dementia', 'heartbroken']
# logos childhood dementia heartbroken
# ['three', 'easy', 'ways', 'to', 'help', 'you', 'beat', 'the', 'winter', 'blues']
# ['three', 'easy', 'ways', 'help', 'beat', 'winter', 'blues']
# three easy ways help beat winter blues
# ['three', 'easy', 'way', 'to', 'aid', 'you', 'beat', 'the', 'winter', 'blues']
# ['three', 'easy', 'way', 'aid', 'beat', 'winter', 'blues']
# three easy way aid beat winter blues
# ['william', 'recalls', 'kate', 'cancer', 'talk', 'with', 'children']
# ['william', 'recalls', 'kate', 'cancer', 'talk', 'children']
# william recalls kate cancer talk children
# ['william', 'recalls', 'kate', 'crab', 'talk', 'with', 'kid']
# ['william', 'recalls', 'kate', 'crab', 'talk', 'kid']
# william recalls kate crab talk kid
# ['canada', 'loses', 'its', 'measlesfree', 'status', 'with', 'us', 'on', 'track', 'to', 'follow']
# ['canada', 'loses', 'measlesfree', 'status', 'us', 'track', 'follow']
# canada loses measlesfree status us track follow
# ['canada', 'recede', 'its', 'morbilli', 'free', 'position', 'with', 'us', 'on', 'cartroad', 'to', 'follow']
# ['canada', 'recede', 'morbilli', 'free', 'position', 'us', 'cartroad', 'follow']
# canada recede morbilli free position us cartroad follow
# ['refinement']
# ['refinement']
# refinement
# ['the', 'truth', 'about', 'tudor', 'englands', 'most', 'hated', 'woman']
# ['truth', 'tudor', 'englands', 'hated', 'woman']
# truth tudor englands hated woman
# ['the', 'truth', 'about', 'house', 'of', 'tudor', 'england', 's', 'nearly', 'scorned', 'woman']
# ['truth', 'house', 'tudor', 'england', 'nearly', 'scorned', 'woman']
# truth house tudor england nearly scorned woman
# ['jilly', 'cooper', 'died', 'from', 'head', 'injury', 'says', 'coroner']
# ['jilly', 'cooper', 'died', 'head', 'injury', 'says', 'coroner']
# jilly cooper died head injury says coroner
# ['jilly', 'cooper', 'died', 'from', 'caput', 'injury', 'says', 'medical', 'examiner']
# ['jilly', 'cooper', 'died', 'caput', 'injury', 'says', 'medical', 'examiner']
# jilly cooper died caput injury says medical examiner
# ['weve', 'got', 'to', 'fight', 'for', 'our', 'journalism', 'bbc', 'director', 'general', 'tells', 'staff']
# ['weve', 'got', 'fight', 'journalism', 'bbc', 'director', 'general', 'tells', 'staff']
# weve got fight journalism bbc director general tells staff
# ['we', 've', 'got', 'to', 'fight', 'for', 'our', 'news', 'media', 'bbc', 'director', 'general', 'tells', 'stave']
# ['got', 'fight', 'news', 'media', 'bbc', 'director', 'general', 'tells', 'stave']
# got fight news media bbc director general tells stave
# ['ariana', 'grande', 'going', 'brunette', 'is', 'not', 'about', 'saying', 'goodbye', 'to', 'glinda']
# ['ariana', 'grande', 'going', 'brunette', 'saying', 'goodbye', 'glinda']
# ariana grande going brunette saying goodbye glinda
# ['ariana', 'grande', 'lead', 'brunette', 'follow', 'not', 'about', 'saying', 'auf', 'wiedersehen', 'to', 'glinda']
# ['ariana', 'grande', 'lead', 'brunette', 'follow', 'saying', 'auf', 'wiedersehen', 'glinda']
# ariana grande lead brunette follow saying auf wiedersehen glinda
# ['arts']
# ['arts']
# arts
# ['artwork']
# ['artwork']
# artwork
# ['why', 'historys', 'most', 'controversial', 'queen', 'was', 'so', 'hated']
# ['historys', 'controversial', 'queen', 'hated']
# historys controversial queen hated
# ['why', 'history', 's', 'most', 'controversial', 'pouf', 'was', 'so', 'detested']
# ['history', 'controversial', 'pouf', 'detested']
# history controversial pouf detested
# ['the', 'chair', 'that', 'took', 'hours', 'to', 'create']
# ['chair', 'took', 'hours', 'create']
# chair took hours create
# ['the', 'chair', 'that', 'took', 'tenner', 'hour', 'to', 'make']
# ['chair', 'took', 'tenner', 'hour', 'make']
# chair took tenner hour make
# ['why', 'a', 'poem', 'outraged', 's', 'britain']
# ['poem', 'outraged', 'britain']
# poem outraged britain
# ['why', 'a', 'poem', 'scandalise', 's', 'uk']
# ['poem', 'scandalise', 'uk']
# poem scandalise uk
# ['the', 'clues', 'hidden', 'in', 'a', 'truecrime', 'masterpiece']
# ['clues', 'hidden', 'truecrime', 'masterpiece']
# clues hidden truecrime masterpiece
# ['the', 'clew', 'hidden', 'in', 'a', 'true', 'crime', 'chef', 'doeuvre']
# ['clew', 'hidden', 'true', 'crime', 'chef', 'doeuvre']
# clew hidden true crime chef doeuvre
# ['watch']
# ['watch']
# watch
# ['ticker']
# ['ticker']
# ticker
# ['lion', 'saves', 'pregnant', 'hyena', 'from', 'dotty', 'canis', 'familiaris', 'attack']
# ['lion', 'saves', 'pregnant', 'hyena', 'dotty', 'canis', 'familiaris', 'attack']
# lion saves pregnant hyena dotty canis familiaris attack
# ['travel']
# ['travel']
# travel
# ['locomotion']
# ['locomotion']
# locomotion
# ['where', 'to', 'find', 'bostons', 'best', 'clam', 'chowder']
# ['find', 'bostons', 'best', 'clam', 'chowder']
# find bostons best clam chowder
# ['where', 'to', 'find', 'boston', 's', 'best', 'buck', 'chowder']
# ['find', 'boston', 'best', 'buck', 'chowder']
# find boston best buck chowder
# ['why', 'you', 'should', 'book', 'your', 'eclipse', 'trip', 'today']
# ['book', 'eclipse', 'trip', 'today']
# book eclipse trip today
# ['wherefore', 'you', 'should', 'book', 'your', 'eclipse', 'misstep', 'today']
# ['wherefore', 'book', 'eclipse', 'misstep', 'today']
# wherefore book eclipse misstep today
# ['how', 'soon', 'is', 'too', 'soon', 'to', 'visit', 'after', 'a', 'disaster']
# ['soon', 'soon', 'visit', 'disaster']
# soon soon visit disaster
# ['how', 'soon', 'be', 'too', 'soon', 'to', 'visit', 'after', 'a', 'catastrophe']
# ['soon', 'soon', 'visit', 'catastrophe']
# soon soon visit catastrophe
# ['five', 'of', 'the', 'best', 'rooftop', 'bars', 'in', 'chicago']
# ['five', 'best', 'rooftop', 'bars', 'chicago']
# five best rooftop bars chicago
# ['five', 'of', 'the', 'right', 'rooftop', 'bars', 'in', 'chicago']
# ['five', 'right', 'rooftop', 'bars', 'chicago']
# five right rooftop bars chicago
# ['worlds', 'table']
# ['worlds', 'table']
# worlds table
# ['cosmos', 's', 'table']
# ['cosmos', 'table']
# cosmos table
# ['what', 'mamdanis', 'win', 'means', 'for', 'nycs', 'food', 'scene']
# ['mamdanis', 'win', 'means', 'nycs', 'food', 'scene']
# mamdanis win means nycs food scene
# ['what', 'mamdani', 's', 'profits', 'means', 'for', 'nyc', 's', 'intellectual', 'nourishment', 'scene']
# ['mamdani', 'profits', 'means', 'nyc', 'intellectual', 'nourishment', 'scene']
# mamdani profits means nyc intellectual nourishment scene
# ['why', 'marseille', 'restaurants', 'are', 'offering', 'gourmet', 'food', 'for']
# ['marseille', 'restaurants', 'offering', 'gourmet', 'food']
# marseille restaurants offering gourmet food
# ['why', 'marseille', 'eating', 'place', 'are', 'offering', 'foodie', 'food', 'for', 'thought', 'for']
# ['marseille', 'eating', 'place', 'offering', 'foodie', 'food', 'thought']
# marseille eating place offering foodie food thought
# ['dishes', 'in', 'days', 'indias', 'epic', 'wedding', 'feast']
# ['dishes', 'days', 'indias', 'epic', 'wedding', 'feast']
# dishes days indias epic wedding feast
# ['dish', 'in', 'daytime', 'india', 'south', 'epic', 'wedding', 'feast']
# ['dish', 'daytime', 'india', 'south', 'epic', 'wedding', 'feast']
# dish daytime india south epic wedding feast
# ['the', 'controversial', 'snack', 'that', 'fuels', 'norwegian', 'trips']
# ['controversial', 'snack', 'fuels', 'norwegian', 'trips']
# controversial snack fuels norwegian trips
# ['the', 'controversial', 'snack', 'that', 'fuels', 'norse', 'trips']
# ['controversial', 'snack', 'fuels', 'norse', 'trips']
# controversial snack fuels norse trips
# ['earth']
# ['earth']
# earth
# ['earthly', 'concern']
# ['earthly', 'concern']
# earthly concern
# ['new', 'lucifer', 'bee', 'with', 'devillike', 'horns', 'found', 'in', 'australia']
# ['new', 'lucifer', 'bee', 'devillike', 'horns', 'found', 'australia']
# new lucifer bee devillike horns found australia
# ['new', 'the', 'tempter', 'bee', 'with', 'devil', 'like', 'horns', 'found', 'in', 'commonwealth', 'of', 'australia']
# ['new', 'tempter', 'bee', 'devil', 'like', 'horns', 'found', 'commonwealth', 'australia']
# new tempter bee devil like horns found commonwealth australia
# ['this', 'animal', 'spared', 'my', 'life', 'biologist', 'bitten', 'in', 'head', 'by', 'shark', 'hopes', 'to', 'meet', 'it', 'again']
# ['animal', 'spared', 'life', 'biologist', 'bitten', 'head', 'shark', 'hopes', 'meet']
# animal spared life biologist bitten head shark hopes meet
# ['this', 'animal', 'spar', 'my', 'life', 'life', 'scientist', 'bitten', 'in', 'head', 'by', 'shark', 'hope', 'to', 'encounter', 'it', 'again']
# ['animal', 'spar', 'life', 'life', 'scientist', 'bitten', 'head', 'shark', 'hope', 'encounter']
# animal spar life life scientist bitten head shark hope encounter
# ['once', 'a', 'sure', 'thing', 'australias', 'bid', 'to', 'host', 'cop', 'falters', 'amid', 'deadlock', 'with', 'turkey']
# ['sure', 'thing', 'australias', 'bid', 'host', 'cop', 'falters', 'amid', 'deadlock', 'turkey']
# sure thing australias bid host cop falters amid deadlock turkey
# ['once', 'a', 'trusted', 'thing', 'australia', 'randomness', 'bid', 'to', 'host', 'cop', 'falters', 'amid', 'deadlock', 'with', 'turkey']
# ['trusted', 'thing', 'australia', 'randomness', 'bid', 'host', 'cop', 'falters', 'amid', 'deadlock', 'turkey']
# trusted thing australia randomness bid host cop falters amid deadlock turkey
# ['saving', 'the', 'amazons', 'mystical', 'pink', 'river', 'dolphins']
# ['saving', 'amazons', 'mystical', 'pink', 'river', 'dolphins']
# saving amazons mystical pink river dolphins
# ['saving', 'the', 'amazon', 'river', 's', 'occult', 'pinko', 'river', 'dolphins']
# ['saving', 'amazon', 'river', 'occult', 'pinko', 'river', 'dolphins']
# saving amazon river occult pinko river dolphins
# ['video']
# ['video']
# video
# ['telecasting']
# ['telecasting']
# telecasting
# ['a', 'rare', 'glimpse', 'into', 'the', 'worlds', 'most', 'trafficked', 'mammal']
# ['rare', 'glimpse', 'worlds', 'trafficked', 'mammal']
# rare glimpse worlds trafficked mammal
# ['a', 'rare', 'glance', 'into', 'the', 'world', 's', 'most', 'trafficked', 'mammalian']
# ['rare', 'glance', 'world', 'trafficked', 'mammalian']
# rare glance world trafficked mammalian
# ['why', 'your', 'brain', 'cant', 'help', 'copying', 'the', 'way', 'others', 'speak']
# ['brain', 'cant', 'help', 'copying', 'way', 'others', 'speak']
# brain cant help copying way others speak
# ['why', 'your', 'brain', 'can', 't', 'assistance', 'simulate', 'the', 'way', 'others', 'speak']
# ['brain', 'assistance', 'simulate', 'way', 'others', 'speak']
# brain assistance simulate way others speak
# ['what', 'lies', 'behind', 'kazakhstans', 'mysterious', 'stone', 'spheres']
# ['lies', 'behind', 'kazakhstans', 'mysterious', 'stone', 'spheres']
# lies behind kazakhstans mysterious stone spheres
# ['what', 'lies', 'behind', 'kazakh', 's', 'mysterious', 'pit', 'spheres']
# ['lies', 'behind', 'kazakh', 'mysterious', 'pit', 'spheres']
# lies behind kazakh mysterious pit spheres
# ['dstdning', 'the', 'gentle', 'art', 'of', 'swedish', 'death', 'cleaning']
# ['dstdning', 'gentle', 'art', 'swedish', 'death', 'cleaning']
# dstdning gentle art swedish death cleaning
# ['dstdning', 'the', 'gentle', 'nontextual', 'matter', 'of', 'swedish', 'expiry', 'cleaning']
# ['dstdning', 'gentle', 'nontextual', 'matter', 'swedish', 'expiry', 'cleaning']
# dstdning gentle nontextual matter swedish expiry cleaning
# ['discover', 'more', 'from', 'the', 'bbc']
# ['discover', 'bbc']
# discover bbc
# ['us', 'politics', 'unspun']
# ['us', 'politics', 'unspun']
# us politics unspun
# ['download', 'the', 'bbc', 'app']
# ['download', 'bbc', 'app']
# download bbc app
# ['sign', 'up', 'to', 'world', 'of', 'business']
# ['sign', 'world', 'business']
# sign world business
# ['sign', 'upwards', 'to', 'world', 'of', 'business']
# ['sign', 'upwards', 'world', 'business']
# sign upwards world business
# ['register', 'for', 'a', 'bbc', 'account']
# ['register', 'bbc', 'account']
# register bbc account
# ['sign', 'up', 'for', 'the', 'essential', 'list']
# ['sign', 'essential', 'list']
# sign essential list
# ['signboard', 'up', 'for', 'the', 'essential', 'list']
# ['signboard', 'essential', 'list']
# signboard essential list
# ['cop', 'in', 'brazil']
# ['cop', 'brazil']
# cop brazil
# ['islamabad', 'suicide', 'attack']
# ['islamabad', 'suicide', 'attack']
# islamabad suicide attack
# ['islamabad', 'felo', 'de', 'se', 'attack']
# ['islamabad', 'felo', 'de', 'se', 'attack']
# islamabad felo de se attack
# ['what', 'is', 'project', 'athena']
# ['project', 'athena']
# project athena
# ['what', 'is', 'task', 'athena']
# ['task', 'athena']
# task athena
# ['futuristic', 'planes']
# ['futuristic', 'planes']
# futuristic planes
# ['futuristic', 'airplane']
# ['futuristic', 'airplane']
# futuristic airplane
# ['sinneralcaraz', 'rivalry']
# ['sinneralcaraz', 'rivalry']
# sinneralcaraz rivalry
# ['sinner', 'alcaraz', 'rivalry']
# ['sinner', 'alcaraz', 'rivalry']
# sinner alcaraz rivalry
# ['how', 'to', 'snoreproof', 'sexual', 'relationships']
# ['snoreproof', 'sexual', 'relationships']
# snoreproof sexual relationships
# ['how', 'to', 'snore', 'proof', 'sexual', 'relationship']
# ['snore', 'proof', 'sexual', 'relationship']
# snore proof sexual relationship
# ['toy', 'story']
# ['toy', 'story']
# toy story
# ['toy', 'write', 'up']
# ['toy', 'write']
# toy write
# ['as', 'us', 'house', 'of', 'representatives', 'reopens', 'for', 'key', 'vote', 'things', 'may', 'worsen', 'for', 'speaker', 'johnson']
# ['us', 'house', 'representatives', 'reopens', 'key', 'vote', 'things', 'may', 'worsen', 'speaker', 'johnson']
# us house representatives reopens key vote things may worsen speaker johnson
# ['as', 'us', 'house', 'of', 'spokesperson', 'reopens', 'for', 'key', 'vote', 'things', 'may', 'worsen', 'for', 'speaker', 'system', 'lyndon', 'johnson']
# ['us', 'house', 'spokesperson', 'reopens', 'key', 'vote', 'things', 'may', 'worsen', 'speaker', 'system', 'lyndon', 'johnson']
# us house spokesperson reopens key vote things may worsen speaker system lyndon johnson
# ['whats', 'in', 'the', 'bill', 'to', 'reopen', 'the', 'federal', 'government']
# ['whats', 'bill', 'reopen', 'federal', 'government']
# whats bill reopen federal government
# ['what', 'mho', 'in', 'the', 'federal', 'reserve', 'note', 'to', 'reopen', 'the', 'union', 'government']
# ['mho', 'federal', 'reserve', 'note', 'reopen', 'union', 'government']
# mho federal reserve note reopen union government
# ['bridge', 'partially', 'collapses', 'in', 'china']
# ['bridge', 'partially', 'collapses', 'china']
# bridge partially collapses china
# ['bridge', 'partially', 'collapses', 'in', 'republic', 'of', 'china']
# ['bridge', 'partially', 'collapses', 'republic', 'china']
# bridge partially collapses republic china
# ['he', 'was', 'dictator', 'who', 'led', 'sweeping', 'massacres', 'why', 'is', 'he', 'now', 'a', 'national', 'hero']
# ['dictator', 'led', 'sweeping', 'massacres', 'national', 'hero']
# dictator led sweeping massacres national hero
# ['he', 'cost', 'dictator', 'world', 'health', 'organization', 'lead', 'sweeping', 'massacres', 'why', 'constitute', 'he', 'now', 'a', 'national', 'hero']
# ['cost', 'dictator', 'world', 'health', 'organization', 'lead', 'sweeping', 'massacres', 'constitute', 'national', 'hero']
# cost dictator world health organization lead sweeping massacres constitute national hero
# ['decision', 'comes', 'amid', 'concerns', 'about', 'the', 'legality', 'of', 'us', 'military', 'strikes', 'on', 'alleged', 'drug', 'boats', 'sources', 'tell', 'cnn']
# ['decision', 'comes', 'amid', 'concerns', 'legality', 'us', 'military', 'strikes', 'alleged', 'drug', 'boats', 'sources', 'tell', 'cnn']
# decision comes amid concerns legality us military strikes alleged drug boats sources tell cnn
# ['decision', 'comes', 'amid', 'concerns', 'about', 'the', 'legality', 'of', 'us', 'military', 'ten', 'strike', 'on', 'alleged', 'drug', 'boats', 'source', 'tell', 'cnn']
# ['decision', 'comes', 'amid', 'concerns', 'legality', 'us', 'military', 'ten', 'strike', 'alleged', 'drug', 'boats', 'source', 'tell', 'cnn']
# decision comes amid concerns legality us military ten strike alleged drug boats source tell cnn
# ['a', 'timeline', 'of', 'us', 'strikes', 'on', 'boats', 'that', 'have', 'killed']
# ['timeline', 'us', 'strikes', 'boats', 'killed']
# timeline us strikes boats killed
# ['a', 'timeline', 'of', 'atomic', 'number', 'strikes', 'on', 'boats', 'that', 'give', 'killed']
# ['timeline', 'atomic', 'number', 'strikes', 'boats', 'give', 'killed']
# timeline atomic number strikes boats give killed
# ['venezuela', 'announces', 'massive', 'mobilization', 'of', 'military', 'forces', 'as', 'us', 'largest', 'warship', 'sails', 'into', 'region']
# ['venezuela', 'announces', 'massive', 'mobilization', 'military', 'forces', 'us', 'largest', 'warship', 'sails', 'region']
# venezuela announces massive mobilization military forces us largest warship sails region
# ['venezuela', 'announces', 'massive', 'militarisation', 'of', 'military', 'forces', 'as', 'uranium', 'big', 'war', 'vessel', 'sails', 'into', 'region']
# ['venezuela', 'announces', 'massive', 'militarisation', 'military', 'forces', 'uranium', 'big', 'war', 'vessel', 'sails', 'region']
# venezuela announces massive militarisation military forces uranium big war vessel sails region
# ['heres', 'what', 'the', 'us', 'military', 'is', 'using', 'to', 'strike', 'alleged', 'drug', 'boats']
# ['heres', 'us', 'military', 'using', 'strike', 'alleged', 'drug', 'boats']
# heres us military using strike alleged drug boats
# ['here', 's', 'what', 'the', 'us', 'military', 'is', 'apply', 'to', 'strike', 'alleged', 'drug', 'boats']
# ['us', 'military', 'apply', 'strike', 'alleged', 'drug', 'boats']
# us military apply strike alleged drug boats
# ['catch', 'up', 'on', 'todays', 'global', 'news']
# ['catch', 'todays', 'global', 'news']
# catch todays global news
# ['catch', 'up', 'on', 'today', 's', 'spherical', 'news']
# ['catch', 'today', 'spherical', 'news']
# catch today spherical news
# ['breathtaking', 'northern', 'lights', 'splash', 'across', 'the', 'night', 'skies', 'as', 'far', 'south', 'as', 'florida']
# ['breathtaking', 'northern', 'lights', 'splash', 'across', 'night', 'skies', 'far', 'south', 'florida']
# breathtaking northern lights splash across night skies far south florida
# ['breathtaking', 'northern', 'lighting', 'plash', 'across', 'the', 'night', 'sky', 'as', 'far', 'south', 'as', 'florida']
# ['breathtaking', 'northern', 'lighting', 'plash', 'across', 'night', 'sky', 'far', 'south', 'florida']
# breathtaking northern lighting plash across night sky far south florida
# ['horizon', 'planes', 'futuristic', 'shape', 'could', 'revolutionize', 'flying']
# ['horizon', 'planes', 'futuristic', 'shape', 'could', 'revolutionize', 'flying']
# horizon planes futuristic shape could revolutionize flying
# ['horizon', 'plane', 's', 'futuristic', 'shape', 'could', 'revolutionize', 'fly']
# ['horizon', 'plane', 'futuristic', 'shape', 'could', 'revolutionize', 'fly']
# horizon plane futuristic shape could revolutionize fly
# ['how', 'it', 'feels', 'to', 'spend', 'm', 'on', 'a', 'bag', 'according', 'to', 'the', 'man', 'who', 'did', 'it']
# ['feels', 'spend', 'bag', 'according', 'man']
# feels spend bag according man
# ['how', 'information', 'technology', 'find', 'to', 'spend', 'm', 'on', 'a', 'bag', 'allot', 'to', 'the', 'man', 'who', 'did', 'it']
# ['information', 'technology', 'find', 'spend', 'bag', 'allot', 'man']
# information technology find spend bag allot man
# ['screens', 'are', 'the', 'enemy', 'in', 'new', 'toy', 'story', 'teaser', 'trailer']
# ['screens', 'enemy', 'new', 'toy', 'story', 'teaser', 'trailer']
# screens enemy new toy story teaser trailer
# ['screens', 'be', 'the', 'enemy', 'in', 'fresh', 'toy', 'story', 'teaser', 'trailer']
# ['screens', 'enemy', 'fresh', 'toy', 'story', 'teaser', 'trailer']
# screens enemy fresh toy story teaser trailer
# ['dozens', 'of', 'israeli', 'settlers', 'launch', 'arson', 'attack', 'in', 'west', 'bank', 'as', 'attacks', 'against', 'palestinians', 'surge']
# ['dozens', 'israeli', 'settlers', 'launch', 'arson', 'attack', 'west', 'bank', 'attacks', 'palestinians', 'surge']
# dozens israeli settlers launch arson attack west bank attacks palestinians surge
# ['twelve', 'of', 'israeli', 'settlers', 'launch', 'arson', 'flack', 'in', 'west', 'bank', 'building', 'as', 'attacks', 'against', 'palestinian', 'surge']
# ['twelve', 'israeli', 'settlers', 'launch', 'arson', 'flack', 'west', 'bank', 'building', 'attacks', 'palestinian', 'surge']
# twelve israeli settlers launch arson flack west bank building attacks palestinian surge
# ['two', 'of', 'chinas', 'most', 'popular', 'gay', 'dating', 'apps', 'have', 'disappeared', 'from', 'app', 'stores']
# ['two', 'chinas', 'popular', 'gay', 'dating', 'apps', 'disappeared', 'app', 'stores']
# two chinas popular gay dating apps disappeared app stores
# ['two', 'of', 'china', 's', 'most', 'popular', 'homophile', 'go', 'out', 'apps', 'have', 'go', 'away', 'from', 'app', 'stores']
# ['two', 'china', 'popular', 'homophile', 'go', 'apps', 'go', 'away', 'app', 'stores']
# two china popular homophile go apps go away app stores
# ['search', 'continues', 'for', 'rohingya', 'refugees', 'after', 'boat', 'capsizes']
# ['search', 'continues', 'rohingya', 'refugees', 'boat', 'capsizes']
# search continues rohingya refugees boat capsizes
# ['search', 'continue', 'for', 'rohingya', 'refugees', 'after', 'boat', 'capsizes']
# ['search', 'continue', 'rohingya', 'refugees', 'boat', 'capsizes']
# search continue rohingya refugees boat capsizes
# ['at', 'least', 'killed', 'in', 'islamabad', 'suicide', 'attack', 'the', 'most', 'deadly', 'assault', 'in', 'the', 'pakistani', 'capital', 'since']
# ['least', 'killed', 'islamabad', 'suicide', 'attack', 'deadly', 'assault', 'pakistani', 'capital', 'since']
# least killed islamabad suicide attack deadly assault pakistani capital since
# ['at', 'least', 'defeat', 'in', 'islamabad', 'suicide', 'onslaught', 'the', 'most', 'deadly', 'assault', 'in', 'the', 'pakistani', 'das', 'kapital', 'since']
# ['least', 'defeat', 'islamabad', 'suicide', 'onslaught', 'deadly', 'assault', 'pakistani', 'das', 'kapital', 'since']
# least defeat islamabad suicide onslaught deadly assault pakistani das kapital since
# ['footage', 'shows', 'russian', 'troops', 'approaching', 'key', 'ukrainian', 'city']
# ['footage', 'shows', 'russian', 'troops', 'approaching', 'key', 'ukrainian', 'city']
# footage shows russian troops approaching key ukrainian city
# ['footage', 'present', 'russian', 'troops', 'approaching', 'key', 'ukrainian', 'metropolis']
# ['footage', 'present', 'russian', 'troops', 'approaching', 'key', 'ukrainian', 'metropolis']
# footage present russian troops approaching key ukrainian metropolis
# ['venezuelans', 'deported', 'from', 'us', 'to', 'salvadoran', 'prison', 'subjected', 'to', 'torture', 'rights', 'groups', 'claim', 'in', 'new', 'report']
# ['venezuelans', 'deported', 'us', 'salvadoran', 'prison', 'subjected', 'torture', 'rights', 'groups', 'claim', 'new', 'report']
# venezuelans deported us salvadoran prison subjected torture rights groups claim new report
# ['venezuelans', 'comport', 'from', 'us', 'to', 'salvadoran', 'prison', 'subjected', 'to', 'torture', 'rights', 'chemical', 'group', 'lay', 'claim', 'in', 'new', 'report', 'card']
# ['venezuelans', 'comport', 'us', 'salvadoran', 'prison', 'subjected', 'torture', 'rights', 'chemical', 'group', 'lay', 'claim', 'new', 'report', 'card']
# venezuelans comport us salvadoran prison subjected torture rights chemical group lay claim new report card
# ['this', 'portrait', 'could', 'become', 'one', 'of', 'most', 'expensive', 'paintings', 'ever', 'publicly', 'sold']
# ['portrait', 'could', 'become', 'one', 'expensive', 'paintings', 'ever', 'publicly', 'sold']
# portrait could become one expensive paintings ever publicly sold
# ['this', 'portrait', 'could', 'go', 'nonpareil', 'of', 'near', 'expensive', 'paintings', 'ever', 'publicly', 'sold']
# ['portrait', 'could', 'go', 'nonpareil', 'near', 'expensive', 'paintings', 'ever', 'publicly', 'sold']
# portrait could go nonpareil near expensive paintings ever publicly sold
# ['unseen', 'photos', 'reveal', 'another', 'side', 'to', 's', 'lagos']
# ['unseen', 'photos', 'reveal', 'another', 'side', 'lagos']
# unseen photos reveal another side lagos
# ['unobserved', 'pic', 'reveal', 'another', 'side', 'to', 's', 'lagos']
# ['unobserved', 'pic', 'reveal', 'another', 'side', 'lagos']
# unobserved pic reveal another side lagos
# ['a', 'block', 'of', 'white', 'and', 'green', 'jadeite', 'has', 'its', 'own', 'exhibition', 'hall', 'in', 'taiwan', 'heres', 'why', 'its', 'so', 'endearing']
# ['block', 'white', 'green', 'jadeite', 'exhibition', 'hall', 'taiwan', 'heres', 'endearing']
# block white green jadeite exhibition hall taiwan heres endearing
# ...
# ['latest', 'chapter', 'sincaraz', 'rivalry', 'turin', 'brings', 'curtain', 'year', 'dominance']
# latest chapter sincaraz rivalry turin brings curtain year dominance
# ['the', 'latest', 'chapter', 'of', 'the', 'sincaraz', 'rivalry', 'in', 'turin', 'brings', 'curtain', 'down', 'on', 'twelvemonth', 'of', 'ascendancy']
# ['latest', 'chapter', 'sincaraz', 'rivalry', 'turin', 'brings', 'curtain', 'twelvemonth', 'ascendancy']
# latest chapter sincaraz rivalry turin brings curtain twelvemonth ascendancy
# ['paris', 'jackson', 'reveals', 'she', 'has', 'a', 'perforated', 'septum', 'dont', 'do', 'drugs', 'kids']
# ['paris', 'jackson', 'reveals', 'perforated', 'septum', 'dont', 'drugs', 'kids']
# paris jackson reveals perforated septum dont drugs kids
# ['city', 'of', 'light', 'jackson', 'reveals', 'she', 'has', 'a', 'perforate', 'septum', 'don', 'river', 't', 'do', 'drugs', 'kids']
# ['city', 'light', 'jackson', 'reveals', 'perforate', 'septum', 'river', 'drugs', 'kids']
# city light jackson reveals perforate septum river drugs kids
# ['afghan', 'women', 'not', 'allowed', 'into', 'hospitals', 'without', 'burqas']
# ['afghan', 'women', 'allowed', 'hospitals', 'without', 'burqas']
# afghan women allowed hospitals without burqas
# ['afghan', 'woman', 'non', 'allowed', 'into', 'hospitals', 'without', 'burqas']
# ['afghan', 'woman', 'non', 'allowed', 'hospitals', 'without', 'burqas']
# afghan woman non allowed hospitals without burqas
# ['is', 'having', 'a', 'boyfriend', 'embarrassing', 'now', 'cnn', 'speaks', 'to', 'author']
# ['boyfriend', 'embarrassing', 'cnn', 'speaks', 'author']
# boyfriend embarrassing cnn speaks author
# ['cost', 'having', 'a', 'boyfriend', 'embarrassing', 'at', 'present', 'cnn', 'speaks', 'to', 'author']
# ['cost', 'boyfriend', 'embarrassing', 'present', 'cnn', 'speaks', 'author']
# cost boyfriend embarrassing present cnn speaks author
# ['cnn', 'asks', 'ronaldo', 'if', 'he', 'will', 'play', 'in', 'next', 'world', 'cup']
# ['cnn', 'asks', 'ronaldo', 'play', 'next', 'world', 'cup']
# cnn asks ronaldo play next world cup
# ['cnn', 'asks', 'ronaldo', 'if', 'helium', 'will', 'dally', 'in', 'next', 'populace', 'cup']
# ['cnn', 'asks', 'ronaldo', 'helium', 'dally', 'next', 'populace', 'cup']
# cnn asks ronaldo helium dally next populace cup
# ['tennis', 'icons', 'discuss', 'their', 'rivalry']
# ['tennis', 'icons', 'discuss', 'rivalry']
# tennis icons discuss rivalry
# ['lawn', 'tennis', 'icon', 'discuss', 'their', 'rivalry']
# ['lawn', 'tennis', 'icon', 'discuss', 'rivalry']
# lawn tennis icon discuss rivalry
# ['the', 'tallest', 'king', 'and', 'queen', 'of', 'new', 'york', 'were', 'crowned']
# ['tallest', 'king', 'queen', 'new', 'york', 'crowned']
# tallest king queen new york crowned
# ['the', 'tallest', 'king', 'and', 'queer', 'of', 'new', 'york', 'constitute', 'crown']
# ['tallest', 'king', 'queer', 'new', 'york', 'constitute', 'crown']
# tallest king queer new york constitute crown
# ['travelers', 'and', 'stave', 'left', 'stranded', 'after', 'hotel', 'chain', 's', 'sudden', 'closure']
# ['travelers', 'stave', 'left', 'stranded', 'hotel', 'chain', 'sudden', 'closure']
# travelers stave left stranded hotel chain sudden closure
# ['jfks', 'grandson', 'announces', 'run', 'for', 'congress']
# ['jfks', 'grandson', 'announces', 'run', 'congress']
# jfks grandson announces run congress
# ['jfk', 's', 'grandson', 'announces', 'run', 'for', 'us', 'congress']
# ['jfk', 'grandson', 'announces', 'run', 'us', 'congress']
# jfk grandson announces run us congress
# ['indigenous', 'protesters', 'clash', 'with', 'cop', 'security']
# ['indigenous', 'protesters', 'clash', 'cop', 'security']
# indigenous protesters clash cop security
# ['indigenous', 'protesters', 'clash', 'with', 'cop', 'security', 'measure']
# ['indigenous', 'protesters', 'clash', 'cop', 'security', 'measure']
# indigenous protesters clash cop security measure
# ['venezuela', 'mobilizes', 'forces', 'as', 'largest', 'us', 'warship', 'enters', 'region']
# ['venezuela', 'mobilizes', 'forces', 'largest', 'us', 'warship', 'enters', 'region']
# venezuela mobilizes forces largest us warship enters region
# ['venezuela', 'call', 'up', 'forces', 'as', 'largest', 'us', 'warship', 'enters', 'neighborhood']
# ['venezuela', 'call', 'forces', 'largest', 'us', 'warship', 'enters', 'neighborhood']
# venezuela call forces largest us warship enters neighborhood
# ['erin', 'burnett', 'are', 'you', 'really', 'getting', 'a', 'check']
# ['erin', 'burnett', 'really', 'getting', 'check']
# erin burnett really getting check
# ['erin', 'burnett', 'be', 'you', 'really', 'baffle', 'a', 'two', 'check']
# ['erin', 'burnett', 'really', 'baffle', 'two', 'check']
# erin burnett really baffle two check
# ['house', 'democrat', 'to', 'his', 'republican', 'colleagues', 'where', 'the', 'hell', 'have', 'you', 'been']
# ['house', 'democrat', 'republican', 'colleagues', 'hell']
# house democrat republican colleagues hell
# ['house', 'democrat', 'to', 'his', 'republican', 'colleagues', 'where', 'the', 'hell', 'have', 'you', 'embody']
# ['house', 'democrat', 'republican', 'colleagues', 'hell', 'embody']
# house democrat republican colleagues hell embody
# ['bridge', 'partially', 'collapses', 'in', 'prc']
# ['bridge', 'partially', 'collapses', 'prc']
# bridge partially collapses prc
# ['israeli', 'settlers', 'launch', 'arson', 'attack', 'in', 'occupied', 'west', 'bank']
# ['israeli', 'settlers', 'launch', 'arson', 'attack', 'occupied', 'west', 'bank']
# israeli settlers launch arson attack occupied west bank
# ['israeli', 'settlers', 'launch', 'arson', 'attack', 'in', 'engaged', 'mae', 'west', 'cant']
# ['israeli', 'settlers', 'launch', 'arson', 'attack', 'engaged', 'mae', 'west', 'cant']
# israeli settlers launch arson attack engaged mae west cant
# ['what', 'the', 'next', 'hours', 'may', 'look', 'like', 'for', 'the', 'shutdown']
# ['next', 'hours', 'may', 'look', 'like', 'shutdown']
# next hours may look like shutdown
# ['what', 'the', 'future', 'minute', 'may', 'look', 'like', 'for', 'the', 'shutdown']
# ['future', 'minute', 'may', 'look', 'like', 'shutdown']
# future minute may look like shutdown
# ['footage', 'shows', 'russian', 'troops', 'approaching', 'fundamental', 'ukrainian', 'city']
# ['footage', 'shows', 'russian', 'troops', 'approaching', 'fundamental', 'ukrainian', 'city']
# footage shows russian troops approaching fundamental ukrainian city
# ['uk', 'suspends', 'some', 'intelligence', 'sharing', 'with', 'us', 'over', 'boat', 'strike', 'concerns']
# ['uk', 'suspends', 'intelligence', 'sharing', 'us', 'boat', 'strike', 'concerns']
# uk suspends intelligence sharing us boat strike concerns
# ['uk', 'suspend', 'some', 'intelligence', 'sharing', 'with', 'u', 'over', 'boat', 'strike', 'concerns']
# ['uk', 'suspend', 'intelligence', 'sharing', 'u', 'boat', 'strike', 'concerns']
# uk suspend intelligence sharing u boat strike concerns
# ['families', 'sue', 'camp', 'mystic']
# ['families', 'sue', 'camp', 'mystic']
# families sue camp mystic
# ['families', 'sue', 'encampment', 'mystic']
# ['families', 'sue', 'encampment', 'mystic']
# families sue encampment mystic
# ['homeless', 'graduate', 'cant', 'find', 'fulltime', 'work', 'in', 'nyc']
# ['homeless', 'graduate', 'cant', 'find', 'fulltime', 'work', 'nyc']
# homeless graduate cant find fulltime work nyc
# ['homeless', 'alumna', 'can', 't', 'find', 'full', 'time', 'work', 'in', 'nyc']
# ['homeless', 'alumna', 'find', 'full', 'time', 'work', 'nyc']
# homeless alumna find full time work nyc
# ['theres', 'a', 'dolphin', 'living', 'in', 'the', 'venice', 'canals']
# ['theres', 'dolphin', 'living', 'venice', 'canals']
# theres dolphin living venice canals
# ['there', 's', 'a', 'dolphin', 'life', 'in', 'the', 'venice', 'channel']
# ['dolphin', 'life', 'venice', 'channel']
# dolphin life venice channel
# ['senate', 'candidate', 'is', 'latest', 'politician', 'to', 'scrub', 'defund', 'the', 'police', 'posts']
# ['senate', 'candidate', 'latest', 'politician', 'scrub', 'defund', 'police', 'posts']
# senate candidate latest politician scrub defund police posts
# ['senate', 'candidate', 'is', 'latest', 'political', 'leader', 'to', 'scrub', 'defund', 'the', 'law', 'posts']
# ['senate', 'candidate', 'latest', 'political', 'leader', 'scrub', 'defund', 'law', 'posts']
# senate candidate latest political leader scrub defund law posts
# ['shark', 'tank', 'judge', 'reacts', 'to', 'trumps', 'year', 'mortgage', 'proposal']
# ['shark', 'tank', 'judge', 'reacts', 'trumps', 'year', 'mortgage', 'proposal']
# shark tank judge reacts trumps year mortgage proposal
# ['shark', 'tank', 'judge', 'reacts', 'to', 'trump', 's', 'l', 'year', 'mortgage', 'proposal']
# ['shark', 'tank', 'judge', 'reacts', 'trump', 'l', 'year', 'mortgage', 'proposal']
# shark tank judge reacts trump l year mortgage proposal
# ['popular', 'gay', 'dating', 'apps', 'removed', 'in', 'mainland', 'china']
# ['popular', 'gay', 'dating', 'apps', 'removed', 'mainland', 'china']
# popular gay dating apps removed mainland china
# ['popular', 'gay', 'date', 'apps', 'take', 'away', 'in', 'mainland', 'china']
# ['popular', 'gay', 'date', 'apps', 'take', 'away', 'mainland', 'china']
# popular gay date apps take away mainland china
# ['lookup', 'continues', 'for', 'rohingya', 'refugees', 'after', 'boat', 'capsizes']
# ['lookup', 'continues', 'rohingya', 'refugees', 'boat', 'capsizes']
# lookup continues rohingya refugees boat capsizes
# ['india', 'on', 'high', 'alert', 'after', 'deadly', 'blast']
# ['india', 'high', 'alert', 'deadly', 'blast']
# india high alert deadly blast
# ['republic', 'of', 'india', 'on', 'high', 'alert', 'after', 'devilishly', 'blast']
# ['republic', 'india', 'high', 'alert', 'devilishly', 'blast']
# republic india high alert devilishly blast
# ['volnado', 'spotted', 'near', 'hawaii', 's', 'kilauea', 'volcanic', 'eruption']
# ['volnado', 'spotted', 'near', 'hawaii', 'kilauea', 'volcanic', 'eruption']
# volnado spotted near hawaii kilauea volcanic eruption
# ['meet', 'the', 'welsh', 'puppies', 'that', 'are', 'stopping', 'wildlife', 'poachers', 'in', 'africa']
# ['meet', 'welsh', 'puppies', 'stopping', 'wildlife', 'poachers', 'africa']
# meet welsh puppies stopping wildlife poachers africa
# ['sports', 'meeting', 'the', 'welsh', 'puppies', 'that', 'are', 'stopping', 'wildlife', 'poacher', 'in', 'africa']
# ['sports', 'meeting', 'welsh', 'puppies', 'stopping', 'wildlife', 'poacher', 'africa']
# sports meeting welsh puppies stopping wildlife poacher africa
# ['photos', 'reveal', 'creepy', 'crawlies', 'in', 'extreme', 'detail']
# ['photos', 'reveal', 'creepy', 'crawlies', 'extreme', 'detail']
# photos reveal creepy crawlies extreme detail
# ['picture', 'reveal', 'creepy', 'crawlies', 'in', 'extreme', 'detail']
# ['picture', 'reveal', 'creepy', 'crawlies', 'extreme', 'detail']
# picture reveal creepy crawlies extreme detail
# ['an', 'artist', 'used', 'million', 'beads', 'to', 'transform', 'a', 'supersonic', 'jet']
# ['artist', 'used', 'million', 'beads', 'transform', 'supersonic', 'jet']
# artist used million beads transform supersonic jet
# ['an', 'creative', 'person', 'used', 'xxxv', 'million', 'beads', 'to', 'transmute', 'a', 'supersonic', 'jet']
# ['creative', 'person', 'used', 'xxxv', 'million', 'beads', 'transmute', 'supersonic', 'jet']
# creative person used xxxv million beads transmute supersonic jet
# ['in', 'photos', 'the', 'secretive', 'colorful', 'world', 'of', 'ghanaian', 'funerals']
# ['photos', 'secretive', 'colorful', 'world', 'ghanaian', 'funerals']
# photos secretive colorful world ghanaian funerals
# ['in', 'photos', 'the', 'secretive', 'colored', 'world', 'of', 'ghanian', 'funerals']
# ['photos', 'secretive', 'colored', 'world', 'ghanian', 'funerals']
# photos secretive colored world ghanian funerals
# ['the', 'baguette', 'faces', 'an', 'uncertain', 'future', 'how', 'france', 'is', 'rethinking', 'its', 'iconic', 'loaves']
# ['baguette', 'faces', 'uncertain', 'future', 'france', 'rethinking', 'iconic', 'loaves']
# baguette faces uncertain future france rethinking iconic loaves
# ['the', 'baguette', 'faces', 'an', 'incertain', 'future', 'how', 'france', 'is', 'rethink', 'it', 'iconic', 'loaf']
# ['baguette', 'faces', 'incertain', 'future', 'france', 'rethink', 'iconic', 'loaf']
# baguette faces incertain future france rethink iconic loaf
# ['writer', 'david', 'szalay', 'wins', 'prestigious', 'booker', 'prize', 'for', 'fiction']
# ['writer', 'david', 'szalay', 'wins', 'prestigious', 'booker', 'prize', 'fiction']
# writer david szalay wins prestigious booker prize fiction
# ['writer', 'david', 'szalay', 'gain', 'ground', 'prestigious', 'booker', 'prize', 'for', 'fiction']
# ['writer', 'david', 'szalay', 'gain', 'ground', 'prestigious', 'booker', 'prize', 'fiction']
# writer david szalay gain ground prestigious booker prize fiction
# ['thailand', 'halts', 'peace', 'agreement', 'with', 'cambodia']
# ['thailand', 'halts', 'peace', 'agreement', 'cambodia']
# thailand halts peace agreement cambodia
# ['thailand', 'halts', 'peace', 'agreement', 'with', 'cambodia']
# ['thailand', 'halts', 'peace', 'agreement', 'cambodia']
# thailand halts peace agreement cambodia
# ['former', 'french', 'president', 'sarkozy', 'released', 'from', 'prison', 'pending', 'appeal']
# ['former', 'french', 'president', 'sarkozy', 'released', 'prison', 'pending', 'appeal']
# former french president sarkozy released prison pending appeal
# ['former', 'french', 'president', 'sarkozy', 'release', 'from', 'prison', 'pending', 'appeal']
# ['former', 'french', 'president', 'sarkozy', 'release', 'prison', 'pending', 'appeal']
# former french president sarkozy release prison pending appeal
# ['at', 'least', 'inmates', 'killed', 'by', 'asphyxiation', 'in', 'southern', 'ecuador', 'in', 'wave', 'of', 'prison', 'violence']
# ['least', 'inmates', 'killed', 'asphyxiation', 'southern', 'ecuador', 'wave', 'prison', 'violence']
# least inmates killed asphyxiation southern ecuador wave prison violence
# ['at', 'least', 'inmates', 'stamp', 'out', 'by', 'suffocation', 'in', 'southern', 'republic', 'of', 'ecuador', 'in', 'wave', 'of', 'prison', 'ferocity']
# ['least', 'inmates', 'stamp', 'suffocation', 'southern', 'republic', 'ecuador', 'wave', 'prison', 'ferocity']
# least inmates stamp suffocation southern republic ecuador wave prison ferocity
# ['millions', 'of', 'ukrainians', 'face', 'dark', 'and', 'cold', 'after', 'one', 'of', 'russias', 'largest', 'attacks', 'on', 'energy', 'infrastructure']
# ['millions', 'ukrainians', 'face', 'dark', 'cold', 'one', 'russias', 'largest', 'attacks', 'energy', 'infrastructure']
# millions ukrainians face dark cold one russias largest attacks energy infrastructure
# ['one', 'thousand', 'thousand', 'of', 'ukrainians', 'face', 'dark', 'and', 'cold', 'after', 'one', 'of', 'russia', 's', 'heavy', 'flack', 'on', 'energy', 'infrastructure']
# ['one', 'thousand', 'thousand', 'ukrainians', 'face', 'dark', 'cold', 'one', 'russia', 'heavy', 'flack', 'energy', 'infrastructure']
# one thousand thousand ukrainians face dark cold one russia heavy flack energy infrastructure
# ['syrian', 'migrants', 'in', 'germany', 'face', 'uncertain', 'future', 'as', 'government', 'floats', 'repatriation']
# ['syrian', 'migrants', 'germany', 'face', 'uncertain', 'future', 'government', 'floats', 'repatriation']
# syrian migrants germany face uncertain future government floats repatriation
# ['syrian', 'migrants', 'in', 'germany', 'facial', 'expression', 'uncertain', 'futurity', 'as', 'government', 'floats', 'repatriation']
# ['syrian', 'migrants', 'germany', 'facial', 'expression', 'uncertain', 'futurity', 'government', 'floats', 'repatriation']
# syrian migrants germany facial expression uncertain futurity government floats repatriation
# ['qantas', 'releases', 'first', 'images', 'of', 'jet', 'that', 'will', 'fly', 'nonstop', 'from', 'sydney', 'to', 'london', 'and', 'new', 'york']
# ['qantas', 'releases', 'first', 'images', 'jet', 'fly', 'nonstop', 'sydney', 'london', 'new', 'york']
# qantas releases first images jet fly nonstop sydney london new york
# ['qantas', 'releases', 'first', 'mental', 'image', 'of', 'jet', 'that', 'will', 'aviate', 'nonstop', 'from', 'sydney', 'to', 'london', 'and', 'new', 'house', 'of', 'york']
# ['qantas', 'releases', 'first', 'mental', 'image', 'jet', 'aviate', 'nonstop', 'sydney', 'london', 'new', 'house', 'york']
# qantas releases first mental image jet aviate nonstop sydney london new house york

# %%
stop_words_removal.head()
# Out:
#   Source                                           Headline  \
# 0    BBC  Trump v the BBC: What are the hurdles for US p...
# 1    BBC  Cornet v the BBC: What are the hurdle for US p...
# 2    BBC  Israel has destroyed more than 1,500 buildings...
# 3    BBC  Israel has destroyed more than than ace, 500 b...
# 4    BBC  Trump v the BBC: What are the hurdle for u.s. ...
#
#                                       lower_headline  \
# 0  trump v the bbc: what are the hurdles for us p...
# 1  cornet v the bbc: what are the hurdle for us p...
# 2  israel has destroyed more than 1,500 buildings...
# 3  israel has destroyed more than than ace, 500 b...
# 4  trump v the bbc: what are the hurdle for u.s. ...
#
#                                         cleaned_text  \
# 0  trump v the bbc what are the hurdles for us pr...
# 1  cornet v the bbc what are the hurdle for us pr...
# 2  israel has destroyed more than  buildings in g...
# 3  israel has destroyed more than than ace  build...
# 4  trump v the bbc what are the hurdle for us pre...
#
#                                         No_stopwords
# 0   trump v bbc hurdles us presidents legal argument
# 1  cornet v bbc hurdle us president sound contest...
# 2    israel destroyed buildings gaza since ceasefire
# 3  israel destroyed ace building gaza since cease...
# 4  trump v bbc hurdle us president united states ...

# %%
lemmatizer = WordNetLemmatizer()
stop_words_removal['Lemmatized'] = stop_words_removal['No_stopwords'].apply(
    lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()])
)

# %%
stop_words_removal['No_stopwords'] = (stop_words_removal['No_stopwords'].str.replace(r'\s+', ' ', regex=True).str.strip())

# %%
from collections import Counter
all_words = ' '.join(stop_words_removal['No_stopwords']).split()
word_freq = Counter(all_words)
print(word_freq.most_common(10))
# Out:
# [('us', 35), ('china', 18), ('bbc', 16), ('trump', 15), ('cop', 13), ('attack', 11), ('house', 11), ('new', 11), ('says', 9), ('uk', 9)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=1000)
tfidf_matrix = tfidf.fit_transform(stop_words_removal['No_stopwords'])
print(tfidf_matrix.shape)
# Out:
# (371, 1000)

# %%
stop_words_removal.to_csv('final_cleaned_data.csv', index=False)
